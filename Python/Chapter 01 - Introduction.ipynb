# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# **Exercise 1.1**.  Use software to produce the time series in Exhibit 1.2, on page 2.  The data are in the file named `larain`.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

larain = pd.read_csv('../data/larain.dat')['larain']

plt.figure(figsize=(12, 8))
plt.plot(larain.shift(1), larain, marker='o', markerfacecolor='none', linestyle='none', ms=5, markeredgecolor='blue')
plt.ylabel('Inches')
plt.xlabel('Previous Year Inches')
plt.show()

# %% [markdown]
# **Exercise 1.2**.  Produce the time series plot displayed in Exhibit 1.3, on page 3.  The data file is named color.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

color = pd.read_csv('../data/color.dat')['color']

plt.figure(figsize=(12, 4))
plt.plot(color, marker='o', markerfacecolor='none', linestyle='solid', ms=5, markeredgecolor='blue')
plt.ylabel('Color Property')
plt.xlabel('Batch')
plt.show()

# %% [markdown]
# **Exercise 1.3**.  Simulate a completely random process of length 48 with independent, normal values.  Plot the time series plot.  Does it look "random"?  Repeat this exercise several times with a new simulation each time.

# %%
import numpy as np
from scipy.stats import norm
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(0)

n = 48
plt.figure(figsize=(12, 12))

for i in range(5):
    X = norm.rvs(loc=0, scale=1, size=n)
    ax = plt.subplot(5, 1, i + 1)
    ax.plot(range(1, n+1), X)
    ax.set_xlabel('Observation')
    ax.set_ylabel('Value')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# See the concept of [Apophenia](https://en.wikipedia.org/wiki/Apophenia) for a discussion on seeing patterns in random data.

# %% [markdown]
# **Exercise 1.4**.  Simulate a completely random process of length 48 with independent, chi-square distributed values, each with 2 degrees of freedom.  Display the time series plot.  Does it look "random" and nonnormal?  Repeat this exercise several times with a new simulation each time.

# %%
import numpy as np
from scipy.stats import chi2
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(0)

n = 48
plt.figure(figsize=(12, 12))

for i in range(5):
    X = chi2.rvs(df=2, loc=0, scale=1, size=n)
    ax = plt.subplot(5, 1, i + 1)
    ax.plot(range(1, n+1), X)
    ax.set_xlabel('Observation')
    ax.set_ylabel('Value')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# **Exercise 1.5**.  Simulate a completely random process of length 48 with independent, t-distributed values, each with 5 degrees of freedom.  Display the time series plot.  Does it look "random" and nonnormal?  Repeat this exercise several times with a new simulation each time.

# %%
import numpy as np
from scipy.stats import t
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

np.random.seed(0)

n = 48
plt.figure(figsize=(12, 12))

for i in range(5):
    X = t.rvs(df=5, loc=0, scale=1, size=n)
    ax = plt.subplot(5, 1, i + 1)
    ax.plot(range(1, n+1), X)
    ax.set_xlabel('Observation')
    ax.set_ylabel('Value')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# **Exercise 1.6**.  Construct a time series plot with monthly plotting symbols for the Dubuque temperature series as in Exhibit 1.7, on page 6.  The data are in the file named `tempdub`.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

tempdub = pd.read_csv('../data/tempdub.dat')['tempdub']

plt.figure(figsize=(12, 4))
plt.plot(np.arange(len(tempdub))/12 + 1964, tempdub, marker='o', markerfacecolor='none', linestyle='solid', ms=5)
plt.ylabel('Temperature')
plt.xlabel('Year')
plt.show()
