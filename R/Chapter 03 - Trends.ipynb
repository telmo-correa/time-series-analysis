# %% [markdown]
# ## 3. Trends

# %% [markdown]
# **Exercise 3.1**.  Verify Equation (3.3.2) on page 30, for the least square estimates of $\beta_0$ and $\beta_1$ when the model $Y_t = \beta_0 + \beta_1 t + X_t$ is considered.

# %% [markdown]
# **Solution**.
#
# $$
# \hat{\beta}_1 = \frac{\sum_{t=1}^n(Y_t - \overline{Y})(t - \overline{t})}{\sum_{t=1}^n (t - \overline{t})^2}
# \quad
# \hat{\beta}_0 = \overline{Y} - \hat{\beta}_1 \overline{t}
# \tag{3.3.2}
# $$
#
# The chosen values should minimize
#
# $$ Q(\beta_0, \beta_1) = \sum_{t=1}^n [Y_t - (\beta_0 + \beta_1 t)]^2 $$
#
# Computing the partial derivative with respect to $\beta_0$,
#
# $$ \frac{d Q}{d \beta_0} = \sum_{t=1}^n [-2 (Y_t - \beta_1 t) + 2 \beta_0] = -2 n (\overline{Y} + \beta_1 \overline{t}) + 2 n \beta_0 $$
#
# so the quadratic error is minimized when this expression is 0, or
#
# $$ \hat{\beta}_0 = \overline{Y} - \hat{\beta}_1 \overline{t} $$
#
# Computing the partial derivative with respect to $\beta_1$,
#
# $$ \frac{d Q}{d \beta_1} = \sum_{t=1}^n -2(Y_t t - \beta_0 t - \beta_1 t^2) $$
# m
# Substituting the estimate for $\hat{\beta}_0$ and equating the derivative to 0, we get
#
# $$ \sum_{t=1}^n (Y_t t - \overline{Y}t + \hat{\beta}_1 \overline{t} t - \hat{\beta_1} t^2) = 0 $$
#
# Separating into two sums,
#
# $$ \sum_{t=1}^n t (Y_t - \overline{Y}) - \hat{\beta}_1 \sum_{t=1}^n (t^2 - \overline{t} t) = 0 $$
#
# where, when isolating $\hat{\beta}_1$, gives the result
#
# $$ \hat{\beta}_1
# = \frac{\sum_{t=1}^n (t Y_t - t\overline{Y})}{\sum_{t=1}^n (t^2 - t\overline{t})}
# = \frac{\sum_{t=1}^n (t Y_t - t\overline{Y}) + \sum_{t=1}^n (\overline{t} \overline{Y} - Y_t \overline{t})}{\sum_{t=1}^n (t^2 - t\overline{t}) + \sum_{t=1}^n (\overline{t}^2 - t \overline{t})}
# = \frac{\frac{1}{n}\sum_{t=1}^n(Y_t - \overline{Y})(t - \overline{t})}{\frac{1}{n}\sum_{t=1}^n (t - \overline{t})^2}
# = \frac{\sum_{t=1}^n(Y_t - \overline{Y})(t - \overline{t})}{\sum_{t=1}^n (t - \overline{t})^2}
# $$
#
# The algebraic manipulation becomes somewhat more intuitive using matrix notation,
#
# $$ S(\beta) = (y - X \beta)^T (y - X \beta) $$
#
# is minimized when
#
# $$ 0 = \frac{dS}{d\beta}(\hat{\beta}) = \frac{d}{d\beta} \left( y^T y - \beta^T X^T y - y^T X \beta + \beta^T X^T X \beta \right) |_{\beta=\hat{\beta}} = -2 X^T y + 2 X^T X \hat{\beta} $$
#
# Assuming matrix $X$ has full column rank, then $X^T X$ is invertible, and so
#
# $$ \hat{\beta} = (X^T X)^{-1} X^T y $$

# %% [markdown]
# **Exercise 3.2**.  Suppose $Y_t = \mu + e_t - e_{t - 1}$.  Find $\text{Var}[\overline{Y}]$.  Note any unusual results.  In particular, compare your answer to what would have been obtained if $Y_t = \mu + e_t$.  (Hint: You may avoid Equation (3.2.3) on page 28 by first doing some algebraic simplication on $\sum_{t=1}^n (e_t - e_{t - 1})$.)

# %% [markdown]
# **Solution**.
#
# $$ \text{Var}[\overline{Y}] = \text{Var}\left[ \frac{1}{n} \sum_{t=1}^n Y_t \right] = \text{Var}\left[ \frac{1}{n} \sum_{t=1}^n (\mu + e_t - e_{t-1}) \right] = \text{Var}\left[\mu + \frac{1}{n}(e_{n} - e_{0})\right] = \text{Var}\left[\frac{e_{n}}{n}\right] = \frac{\sigma_e^2}{n^2}$$
#
# If instead we had $Y_t = \mu + e_t$, the result would have been
#
# $$ \text{Var}[\overline{Y}] = \text{Var}\left[ \frac{1}{n} \sum_{t=1}^n Y_t \right] = \text{Var}\left[ \frac{1}{n} \sum_{t=1}^n (\mu + e_t) \right] = \text{Var}\left[\frac{1}{n} \sum_{t=1}^n (e_t) \right] = \frac{1}{n^2} \sum_{t=1}^n \text{Var}[e_t] = \frac{\sigma_e^2}{n}$$
#
# The autocovariance in the error terms meant that the variance of the series average now decays in $O(n^{-2})$ rather than $O(n^{-1})$ with white noise error.

# %% [markdown]
# **Exercise 3.3**.  Suppose $Y_t = \mu + e_t + e_{t-1}$.  Find $\text{Var}[\overline{Y}]$.  Compare your answer to what would have been obtained if $Y_t = \mu + e_t$.  Describe the effect that the autocorrelation in $\{Y_t\}$ has on $\text{Var}[\overline{Y}]$.

# %% [markdown]
# **Solution**.
#
# The variance of $Y_t$ is
#
# $$ \gamma_0 = \text{Var}[Y_t] = \text{Var}[e_t + e_{t - 1}] = 2 \sigma_e^2 $$
#
# and the autocovariance for $k > 0$ is
#
# $$ \gamma_k = \text{Cov}[Y_t, Y_{t - k}] = \begin{cases}
# \text{Cov}[e_{t - 1}, e_{t - 1}] = \sigma_e^2 & \text{for } k = 1 \\
# 0 &\text{for } k > 1
# \end{cases}
# $$
#
# so the autocorrelation is
#
# $$ \rho_k = \begin{cases}
# 1 &\text{for } k = 0 \\
# 1/2 &\text{for } k = 1 \\
# 0 &\text{for } k > 1
# \end{cases} $$
#
# From equation 3.2.3,
#
# $$ \text{Var}[\overline{Y}] = \frac{\gamma_0}{n} \left[ 1 + 2 \sum_{k=1}^{n-1} \left( 1 - \frac{k}{n}\right) \rho_k \right] $$
#
# and in our case
#
# $$ \text{Var}[\overline{Y}] = \frac{2 \sigma_e^2}{n} \left[ 1 + 2 \left(1 - \frac{1}{n}\right) \frac{1}{2} \right] = \sigma_e^2 \frac{2n - 1}{n^2} $$
#
# This also decreases as $O(n^{-1})$, but for sufficiently large $n$ the sample variance is twice as large as it would have been for $Y_t = \mu + e_t$.

# %% [markdown]
# **Exercise 3.4**.  The data file `hours` contains monthly values of the average hours worked per week in the U.S. manufacturing sector for July 1982 through June 1987.
#
# **(a)**  Display and interpret the time series plot for these data.
#
# **(b)**  Now construct a time series plot that uses separate plotting symbols for the various months.  Does your interpretation change from part (a)?

# %% [markdown]
# **Solution**.

# %% [markdown]
# **(a)**

# %%
source('utils.R')
# Out:
# Loading required package: ggplot2
#
# Loading required package: zoo
#
#
# Attaching package: 'zoo'
#
#
# The following objects are masked from 'package:base':
#
#     as.Date, as.Date.numeric

# %%
data <- read.table("../data/hours.dat", header=TRUE)
data['date'] = time(zooreg(1:nrow(data), as.yearmon("1982-07"), freq = 12))
data['t'] = as.numeric(format(data[['date']], "%Y")) + as.numeric(format(data[['date']], "%m"))/12

# %%
options(repr.plot.width=12, repr.plot.height=4)

ggplot(data) + 
  geom_line(aes(x=date, y=hours), color='blue') +
  geom_point(aes(x=date, y=hours), color='blue') +
  xlab('Date') + ylab('Hours') +
  theme_bw() + theme(text = element_text(size=16))
# Out:
# plot without title

# %% [markdown]
# The seasonal patterns are not readily apparent when plotting the data this way, though the smoothness across related data points suggest autocorrelation, and there seems to be an overall trend going up.

# %% [markdown]
# **(b)**

# %%
plot_monthly(data[['date']], data[['hours']], 'Date', 'Hours')
# Out:
# plot without title

# %% [markdown]
# Seasonality is much more apparent now: rise towards December and decay in January / February, and decays in July.

# %% [markdown]
# **Exercise 3.5**.  The data file `wages` contains monthly values of the average hourly wages (in dollars) for workers in the U.S. apparel and textile products industry for July 1981 through June 1987.
#
# **(a)**  Display and interpret the time series plot for these data.
#
# **(b)**  Use least squares to fit a linear time trend to this time series.  Interpret the regression output.  Save the standardized residuals from the fit for further analysis.
#
# **(c)**  Construct and interpret the time series plot of the standardized residuals from part (b).
#
# **(d)**  Use least squares to fit a quadratic time trend to the wages time series.  Interpret the regression output.  Save the standardized residuals from the fit for further analysis.
#
# **(e)**  Construct and interpret the time series plot of the standardized residuals from part (d).

# %% [markdown]
# **Solution**.

# %% [markdown]
# **(a)**

# %%
data <- read.table("../data/wages.dat", header=TRUE)
data['date'] = time(zooreg(1:nrow(data), as.yearmon("1981-07"), freq = 12))
data['t'] = as.numeric(format(data[['date']], "%Y")) + as.numeric(format(data[['date']], "%m"))/12

options(repr.plot.width=12, repr.plot.height=4)

ggplot(data) + 
  geom_line(aes(x=date, y=wages), color='blue') +
  geom_point(aes(x=date, y=wages), color='blue') +
  xlab('Date') + ylab('Hourly wages (dollars)') +
  theme_bw() + theme(text = element_text(size=16))
# Out:
# plot without title

# %% [markdown]
# A drift upward is apparent, with a seasonal dip around August.

# %% [markdown]
# **(b)**

# %%
model = lm(wages ~ t, data=data)
summary(model)
# Out:
# Call:
# lm(formula = wages ~ t, data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.23828 -0.04981  0.01942  0.05845  0.13136
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -5.490e+02  1.115e+01  -49.24   <2e-16 ***
# t            2.811e-01  5.618e-03   50.03   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.08257 on 70 degrees of freedom
# Multiple R-squared:  0.9728,	Adjusted R-squared:  0.9724
# F-statistic:  2503 on 1 and 70 DF,  p-value: < 2.2e-16

# %%
par(mfrow=c(2,2))
options(repr.plot.width=12, repr.plot.height=12)
plot(model)
# Out:
# Plot with title ""

# %% [markdown]
# This seems like a sensible model; fairly high adjusted R squared at 0.972, residuals not too far from 0, QQ-plot close to a diagonal line (so residuals are close to normal), and no points outside Cook's distance (so no meaningful outliers).
#
# That said, the residuals seem to be somewhat cyclical; this will become apparent in (e).

# %% [markdown]
# **(c)**

# %%
data['residuals'] = rstandard(model)

model2 = lm(residuals ~ t, data=data)
summary(model2)
# Out:
# Call:
# lm(formula = residuals ~ t, data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.9604 -0.6060  0.2417  0.7201  1.6079
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  4.263e-01  1.376e+02   0.003    0.998
# t           -2.171e-04  6.936e-02  -0.003    0.998
#
# Residual standard error: 1.019 on 70 degrees of freedom
# Multiple R-squared:  1.4e-07,	Adjusted R-squared:  -0.01429
# F-statistic: 9.799e-06 on 1 and 70 DF,  p-value: 0.9975

# %% [markdown]
# Results are, as expected, not meaningful: the p-value for each coefficient is close to 1.  This is expected, as all explanatory power on a linear model based on the time was already extracted when the first model was computed.

# %% [markdown]
# **(d)**

# %%
model3 = lm(wages ~ t + I(t^2), data=data)
summary(model3)
# Out:
# Call:
# lm(formula = wages ~ t + I(t^2), data = data)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.148318 -0.041440  0.001563  0.050089  0.139839
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -8.496e+04  1.019e+04  -8.336 4.87e-12 ***
# t            8.535e+01  1.027e+01   8.309 5.44e-12 ***
# I(t^2)      -2.143e-02  2.588e-03  -8.282 6.10e-12 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.05889 on 69 degrees of freedom
# Multiple R-squared:  0.9864,	Adjusted R-squared:  0.986
# F-statistic:  2494 on 2 and 69 DF,  p-value: < 2.2e-16

# %%
par(mfrow=c(2,2))
options(repr.plot.width=12, repr.plot.height=12)
plot(model3)
# Out:
# Plot with title ""

# %% [markdown]
# This seems like a slightly better fit, with a higher R adjusted squared and all coefficients being meaningful.  Once again, the diagnostic plots produce no issues of note, other than that residuals seem cyclical; this will become apparent in (e).

# %% [markdown]
# **(e)**

# %%
data['residuals'] = rstandard(model3)

options(repr.plot.width=12, repr.plot.height=4)

ggplot(data) + 
  geom_line(aes(x=date, y=residuals), color='blue') +
  geom_point(aes(x=date, y=residuals), color='blue') +
  xlab('Date') + ylab('Residuals') +
  theme_bw() + theme(text = element_text(size=16))
# Out:
# plot without title

# %%
plot_monthly(data[['date']], data[['residuals']], 'Date', 'Residuals')
# Out:
# plot without title

# %% [markdown]
# This time series seems to indicate a cyclical component on the residuals -- understandable, since it cannot be captured by a linear or quadratic regression.

# %% [markdown]
# **Exercise 3.6**.  The data file `beersales` contains monthly U.S. beer sales (in millions of barrels) for the period January 1975 through December 1990.
#
# **(a)**  Display and interpret the time series plot for these data.
#
# **(b)**  Now construct a time series plot that uses separate plot symbols for the various months.  Does your interpretation change from that in part (a)?
#
# **(c)**  Use least squares to fit a seasonal-means trend to this time series.  Interpret the regression output.  Save the standardized residuals from the fit for further analysis.
#
# **(d)**  Construct and interpret the time series plot of the standardized residuals from part (c).  Be sure to use proper plotting symbols to check on seasonality in the standardized residuals.
#
# **(e)**  Use least squares to fit a seasonal-means plus quadratic time trend to the beer sales time series.  Interpret the regression output.  Save the standardized residuals from the fit for further analysis.
#
# **(f)**  Construct and interpret the time series plot of the standardized residuals from part (e).  Again use proper symbols to check for any remaining seasonality in the residuals.

# %% [markdown]
# **Solution**.

# %% [markdown]
# **(a)**

# %%
data <- read.table("../data/beersales.dat", header=TRUE)
data['date'] = time(zooreg(1:nrow(data), as.yearmon("1975-01"), freq = 12))
data['t'] = as.numeric(format(data[['date']], "%Y")) + as.numeric(format(data[['date']], "%m"))/12
data['month'] = as.factor(format(data[['date']], "%m"))

options(repr.plot.width=12, repr.plot.height=4)

ggplot(data) + 
  geom_line(aes(x=date, y=beersales), color='blue') +
  geom_point(aes(x=date, y=beersales), color='blue') +
  xlab('Date') + ylab('Beer sales (1M barrels)') +
  theme_bw() + theme(text = element_text(size=16))
# Out:
# plot without title

# %% [markdown]
# There seems to be a very strong seasonal component to this series.

# %% [markdown]
# **(b)**

# %%
plot_monthly(data[['date']], data[['beersales']], 'Date', 'Beer sales (1M barrels)')
# Out:
# plot without title

# %% [markdown]
# No change in interpretation -- seasonal component was already very visible.

# %% [markdown]
# **(c)**

# %%
model = lm(beersales ~ month, data=data)
summary(model)
# Out:
# Call:
# lm(formula = beersales ~ month, data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.5745 -0.4772  0.1759  0.7312  2.1023
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 12.48568    0.26392  47.309  < 2e-16 ***
# month02     -0.14259    0.37324  -0.382 0.702879
# month03      2.08219    0.37324   5.579 8.77e-08 ***
# month04      2.39760    0.37324   6.424 1.15e-09 ***
# month05      3.59896    0.37324   9.643  < 2e-16 ***
# month06      3.84976    0.37324  10.314  < 2e-16 ***
# month07      3.76866    0.37324  10.097  < 2e-16 ***
# month08      3.60877    0.37324   9.669  < 2e-16 ***
# month09      1.57282    0.37324   4.214 3.96e-05 ***
# month10      1.25444    0.37324   3.361 0.000948 ***
# month11     -0.04797    0.37324  -0.129 0.897881
# month12     -0.42309    0.37324  -1.134 0.258487
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# ...

# %%
par(mfrow=c(2,2))
options(repr.plot.width=12, repr.plot.height=12)
plot(model)
# Out:
# Plot with title ""

# %% [markdown]
# p-values for 3 of the months seem to be too large, but otherwise this seems to be a sensible model.

# %% [markdown]
# **(d)**

# %%
options(repr.plot.width=12, repr.plot.height=4)
plot_monthly(data[['date']], residuals(model), 'Date', 'Residuals')
# Out:
# plot without title

# %% [markdown]
# The **yearly** seasonal component seems to have been removed -- i.e., July is sometimes up, sometimes down -- but there still seems to be plenty of oscillations, and an overall trend.

# %% [markdown]
# **(e)**

# %%
model2 = lm(beersales ~ month + t + I(t^2), data=data)
summary(model2)
# Out:
# Call:
# lm(formula = beersales ~ month + t + I(t^2), data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -2.03203 -0.43118  0.04977  0.34509  1.57572
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -7.150e+04  8.792e+03  -8.133 6.93e-14 ***
# month02     -1.579e-01  2.090e-01  -0.755  0.45099
# month03      2.052e+00  2.090e-01   9.818  < 2e-16 ***
# month04      2.353e+00  2.090e-01  11.256  < 2e-16 ***
# month05      3.539e+00  2.090e-01  16.934  < 2e-16 ***
# month06      3.776e+00  2.090e-01  18.065  < 2e-16 ***
# month07      3.681e+00  2.090e-01  17.608  < 2e-16 ***
# month08      3.507e+00  2.091e-01  16.776  < 2e-16 ***
# month09      1.458e+00  2.091e-01   6.972 5.89e-11 ***
# month10      1.126e+00  2.091e-01   5.385 2.27e-07 ***
# month11     -1.894e-01  2.091e-01  -0.906  0.36622
# month12     -5.773e-01  2.092e-01  -2.760  0.00638 **
# t            7.196e+01  8.867e+00   8.115 7.70e-14 ***
# ...

# %%
par(mfrow=c(2,2))
options(repr.plot.width=12, repr.plot.height=12)
plot(model2)
# Out:
# Plot with title ""

# %% [markdown]
# R-squared looks much better once we also add quadratic terms for the time.

# %% [markdown]
# **(f)**

# %%
options(repr.plot.width=12, repr.plot.height=4)
plot_monthly(data[['date']], rstandard(model2), 'Date', 'Residuals')
# Out:
# plot without title

# %% [markdown]
# The trend is mostly gone, but there is still non-yearly oscillation in this data.

# %% [markdown]
# **Exercise 3.7**.  The data file `winnebago` contains monthly unit sales of recreational vehicles from Winnebago, Inc. from November 1966 through February 1972.
#
# **(a)**  Display and interpret the time series plot for these data.
#
# **(b)**  Use least squares to fit a line to these data.  Interpret the regression output.  Plot the standardized residuals from the fit as a time series.  Interpret the plot.
#
# **(c)**  Now take the natural logarithms of the monthly sales figures and display and interpret the time series plot of the transformed values.
#
# **(d)**  Use least squares to fit a line through the logged data.  Display and interpret the time series plot of the standardized residuals from this fit.
#
# **(e)**  Now use least squares to fit a seasonal-means plus linear time trend to the logged sales time series and save the standardized residuals for further analysis.  Check the statistical significance of each of the regression coefficients in the model.
#
# **(f)**  Display the time series plot of the standardized residuals obtained in part (e).  Interpret the plot.

# %% [markdown]
# **Solution**.

# %% [markdown]
# **(a)**

# %%
data <- read.table("../data/winnebago.dat", header=TRUE)
data['date'] = time(zooreg(1:nrow(data), as.yearmon("1966-11"), freq = 12))
data['t'] = as.numeric(format(data[['date']], "%Y")) + as.numeric(format(data[['date']], "%m"))/12
data['month'] = as.factor(format(data[['date']], "%m"))

options(repr.plot.width=12, repr.plot.height=4)

ggplot(data) + 
  geom_line(aes(x=date, y=winnebago), color='blue') +
  geom_point(aes(x=date, y=winnebago), color='blue') +
  xlab('Date') + ylab('Monthly unit sales') +
  theme_bw() + theme(text = element_text(size=16))
# Out:
# plot without title

# %% [markdown]
# There seems to be a strong exponential growth component to the series, along with some seasonality.

# %% [markdown]
# **(b)**

# %%
model = lm(winnebago ~ t, data=data)
summary(model)
# Out:
# Call:
# lm(formula = winnebago ~ t, data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -419.58  -93.13  -12.78   94.96  759.21
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -394902.41   33541.19  -11.77   <2e-16 ***
# t               200.74      17.03   11.79   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 209.7 on 62 degrees of freedom
# Multiple R-squared:  0.6915,	Adjusted R-squared:  0.6865
# F-statistic: 138.9 on 1 and 62 DF,  p-value: < 2.2e-16

# %%
par(mfrow=c(2,2))
options(repr.plot.width=12, repr.plot.height=12)
plot(model)
# Out:
# Plot with title ""

# %% [markdown]
# As expected, the R-square is only alright, some points approach Cook's Distance, and the absolute size of the residuals seems to grow with the fitted value.  A linear fit is not very good at describing the series behavior.

# %% [markdown]
# **(c)**

# %%
options(repr.plot.width=12, repr.plot.height=4)

ggplot(data) + 
  geom_line(aes(x=date, y=log(winnebago)), color='blue') +
  geom_point(aes(x=date, y=log(winnebago)), color='blue') +
  xlab('Date') + ylab('log(Monthly unit sales)') +
  theme_bw() + theme(text = element_text(size=16))
# Out:
# plot without title

# %% [markdown]
# The exponential growth now seems linear.

# %% [markdown]
# **(d)**

# %%
model2 = lm(log(winnebago) ~ t, data=data)
summary(model2)
# Out:
# Call:
# lm(formula = log(winnebago) ~ t, data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.03669 -0.20823  0.04995  0.25662  0.86223
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -984.98070   62.99739  -15.63   <2e-16 ***
# t              0.50306    0.03199   15.73   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.3939 on 62 degrees of freedom
# Multiple R-squared:  0.7996,	Adjusted R-squared:  0.7964
# F-statistic: 247.4 on 1 and 62 DF,  p-value: < 2.2e-16

# %%
par(mfrow=c(2,2))
options(repr.plot.width=12, repr.plot.height=12)
plot(model2)
# Out:
# Plot with title ""

# %%
options(repr.plot.width=12, repr.plot.height=4)
plot_monthly(data[['date']], rstandard(model2), 'Date', 'Residuals')
# Out:
# plot without title

# %% [markdown]
# Residuals no longer seem to grow with time -- though there is still a seasonal component (e.g. higher sales in April most years).

# %% [markdown]
# **(e)**

# %%
model3 = lm(log(winnebago) ~ month + t, data=data)
summary(model3)
# Out:
# Call:
# lm(formula = log(winnebago) ~ month + t, data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.92501 -0.16328  0.03344  0.20757  0.57388
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -997.37304   50.64209 -19.695  < 2e-16 ***
# month02        0.62445    0.18182   3.434 0.001188 **
# month03        0.68220    0.19088   3.574 0.000779 ***
# month04        0.80959    0.19079   4.243 9.30e-05 ***
# month05        0.86953    0.19073   4.559 3.25e-05 ***
# month06        0.86309    0.19070   4.526 3.63e-05 ***
# month07        0.55392    0.19069   2.905 0.005420 **
# month08        0.56989    0.19070   2.988 0.004305 **
# month09        0.57572    0.19073   3.018 0.003960 **
# month10        0.26349    0.19079   1.381 0.173300
# month11        0.28682    0.18186   1.577 0.120946
# month12        0.24802    0.18182   1.364 0.178532
# t              0.50909    0.02571  19.800  < 2e-16 ***
# ---
# ...

# %%
par(mfrow=c(2,2))
options(repr.plot.width=12, repr.plot.height=12)
plot(model3)
# Out:
# Plot with title ""

# %% [markdown]
# 3 of the month factor coefficients are not significant; other factors have significant p-values.

# %% [markdown]
# **(f)**

# %%
options(repr.plot.width=12, repr.plot.height=4)
plot_monthly(data[['date']], rstandard(model3), 'Date', 'Residuals')
# Out:
# plot without title

# %% [markdown]
# Residuals still seem to have some auto-correlation, but no yearly component, nor there is a clear trend of growth over time.

# %% [markdown]
# **Exercise 3.8**.  The data file `retail` lists total U.K. (United Kingdom) retail sales (in billions of pounds) from January 1986 through March 2007.  The data are not "seasonally adjusted," and year 2000 = 100 is the base year.
#
# **(a)**  Display and interpret the time series plot for these data.  Be sure to use plotting symbols that permit you to look for seasonality.
#
# **(b)**  Use least squares to fit a seasonal-means plus linear time trend to this time series.  Interpret the regression output and save the standardized residuals from the fit for further analysis.
#
# **(c)**  Construct and interpret the time series plot of the standardized residuals from part (b).  Be sure to use proper plotting symbols to check on seasonality.

# %% [markdown]
# **Solution**.

# %% [markdown]
# **(a)**

# %%
data <- read.table("../data/retail.dat", header=TRUE)
data['date'] = time(zooreg(1:nrow(data), as.yearmon("1986-01"), freq = 12))
data['t'] = as.numeric(format(data[['date']], "%Y")) + as.numeric(format(data[['date']], "%m"))/12
data['month'] = as.factor(format(data[['date']], "%m"))

options(repr.plot.width=12, repr.plot.height=4)

plot_monthly(data[['date']], data[['retail']], 'Date', 'Retail sales')
# Out:
# plot without title

# %% [markdown]
# There are clear seasonal components and linear growth components to this time series.

# %% [markdown]
# **(b)**

# %%
model = lm(retail ~ month + t, data=data)
summary(model)
# Out:
# Call:
# lm(formula = retail ~ month + t, data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -19.8950  -2.4440  -0.3518   2.1971  16.2045
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -7.250e+03  8.724e+01 -83.099  < 2e-16 ***
# month02     -3.015e+00  1.290e+00  -2.337  0.02024 *
# month03      7.469e-02  1.290e+00   0.058  0.95387
# month04      3.447e+00  1.305e+00   2.641  0.00880 **
# month05      3.108e+00  1.305e+00   2.381  0.01803 *
# month06      3.074e+00  1.305e+00   2.355  0.01932 *
# month07      6.053e+00  1.305e+00   4.638 5.76e-06 ***
# month08      3.138e+00  1.305e+00   2.404  0.01695 *
# month09      3.428e+00  1.305e+00   2.626  0.00919 **
# month10      8.555e+00  1.305e+00   6.555 3.34e-10 ***
# month11      2.082e+01  1.305e+00  15.948  < 2e-16 ***
# month12      5.254e+01  1.305e+00  40.255  < 2e-16 ***
# t            3.670e+00  4.369e-02  83.995  < 2e-16 ***
# ---
# ...

# %%
par(mfrow=c(2,2))
options(repr.plot.width=12, repr.plot.height=12)
plot(model)
# Out:
# Plot with title ""

# %% [markdown]
# This regression produces an adjusted R square very close to 1, and most coefficient components (other than March) are significant.

# %% [markdown]
# **(c)**

# %%
options(repr.plot.width=12, repr.plot.height=4)

ggplot(data, aes(x=date)) + 
  geom_line(aes(y=retail, color='Original'), size=0.75) +
  geom_line(aes(y=fitted(model), color='Fitted'), size=0.75) +
  xlab('Date') + ylab('Retail sales') + 
  theme_bw() + theme(text=element_text(size=16)) +
  scale_color_manual(
    values=c("Original" = "blue", "Fitted" = "orange"),
    labels = c("Original", "Fitted")
  ) +
  theme(
    legend.title=element_blank(),
    legend.position = c(.125, .975),
    legend.justification = c("right", "top"),
    legend.box.just = "right",
    legend.margin = margin(6, 6, 6, 6)
  )
# Out:
# plot without title

# %%
plot_monthly(data[['date']], rstandard(model), 'Date', 'Residuals')
# Out:
# plot without title

# %% [markdown]
# There still seems to be some trends in the series that change over time -- in the residuals, December is clearly a set of lower peaks earlier in the series and a set of higher peaks later on.

# %% [markdown]
# **Exercise 3.9**.  The data file `prescrip` gives monthly U.S. prescription costs for the months August 1986 to March 1992.  These data are from the State of New Jersey's Prescription Drug Program and are the cost per prescription claim.
#
# **(a)**  Display and interpret the time series plot for these data.  Use plotting symbols that permit you to look for seasonality.
#
# **(b)**  Calculate and plot the sequence of month-to-month percentage changes in the prescription costs.  Again, use plotting symbols that permit you to look for seasonality.
#
# **(c)**  Use least squares to fit a cosine trend with fundamental frequency 1/12 to the percentage change series.  Interpret the regression output.  Save the standardized residuals.
#
# **(d)**  Plot the sequence of standardized residuals to investigate the adequacy of the cosine trend model.  Interpret the plot.

# %% [markdown]
# **Solution**.

# %% [markdown]
# **(a)**

# %%
data <- read.table("../data/prescrip.dat", header=TRUE)
data['date'] = time(zooreg(1:nrow(data), as.yearmon("1966-11"), freq = 12))
data['t'] = as.numeric(format(data[['date']], "%Y")) + as.numeric(format(data[['date']], "%m"))/12
data['month'] = as.factor(format(data[['date']], "%m"))

options(repr.plot.width=12, repr.plot.height=4)

x = data[['date']]
y = data[['prescrip']]
plot_monthly(x, y, 'Date', 'Prescription costs')
# Out:
# plot without title

# %% [markdown]
# There is both a clear seasonality and a clear growth in this series.

# %% [markdown]
# **(b)**

# %%
require(data.table)

y = data[['prescrip']]
data[['percent_change']] = 100 * (y / shift(y) - 1)

x = data[['date']]
y = data[['percent_change']]
plot_monthly(x, y, 'Date', 'Percent change')
# Out:
# Loading required package: data.table
#
# Warning message:
# "Removed 1 row(s) containing missing values (geom_path)."
# Warning message:
# "Removed 1 rows containing missing values (geom_text)."
# plot without title

# %% [markdown]
# This series looks more well behaved -- with some seasonality, but no clear growth over time.

# %% [markdown]
# **(c)**

# %%
# t is in years, so the fundamental frequency is f = 1/12 year = 1 month

model = lm(percent_change ~ I(cos(2 * pi * t)) + I(sin(2 * pi * t)), data=data)
summary(model)
# Out:
# Call:
# lm(formula = percent_change ~ I(cos(2 * pi * t)) + I(sin(2 *
#     pi * t)), data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.8444 -1.3742  0.1697  1.4069  3.8980
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)          1.2217     0.2325   5.254 1.82e-06 ***
# I(cos(2 * pi * t))  -1.1104     0.3254  -3.413  0.00112 **
# I(sin(2 * pi * t))  -1.3960     0.3313  -4.213 8.04e-05 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.897 on 64 degrees of freedom
#   (1 observation deleted due to missingness)
# Multiple R-squared:  0.3148,	Adjusted R-squared:  0.2933
# F-statistic:  14.7 on 2 and 64 DF,  p-value: 5.584e-06

# %%
par(mfrow=c(2,2))
options(repr.plot.width=12, repr.plot.height=12)
plot(model)
# Out:
# Plot with title ""

# %%
options(repr.plot.width=12, repr.plot.height=4)

ggplot(data[-1,], aes(x=date)) + 
  geom_line(aes(y=percent_change, color='Original'), size=0.75) +
  geom_line(aes(y=fitted(model), color='Fitted'), size=0.75) +
  xlab('Date') + ylab('Percent change') + 
  theme_bw() + theme(text=element_text(size=16)) +
  scale_color_manual(
    values=c("Original" = "blue", "Fitted" = "orange"),
    labels = c("Original", "Fitted")
  ) +
  theme(
    legend.title=element_blank(),
    legend.position = c(.125, .975),
    legend.justification = c("right", "top"),
    legend.box.just = "right",
    legend.margin = margin(6, 6, 6, 6)
  )
# Out:
# plot without title

# %%
fitted_ratio = data[['prescrip']][1] * cumprod(c(1, fitted(model) / 100 + 1))

options(repr.plot.width=12, repr.plot.height=4)

ggplot(data, aes(x=date)) + 
  geom_line(aes(y=prescrip, color='Original'), size=0.75) +
  geom_line(aes(y=fitted_ratio, color='Fitted'), size=0.75) +
  xlab('Date') + ylab('Prescription costs') + 
  theme_bw() + theme(text=element_text(size=16)) +
  scale_color_manual(
    values=c("Original" = "blue", "Fitted" = "orange"),
    labels = c("Original", "Fitted")
  ) +
  theme(
    legend.title=element_blank(),
    legend.position = c(.125, .975),
    legend.justification = c("right", "top"),
    legend.box.just = "right",
    legend.margin = margin(6, 6, 6, 6)
  )
# Out:
# plot without title

# %% [markdown]
# This regression output does have a smaller R squared compared to other examples, but the coefficients have good p-values, and seem to capture the overall series behavior.

# %% [markdown]
# **(d)**

# %%
options(repr.plot.width=12, repr.plot.height=4)

x = data[['date']][2:68]
y = rstandard(model)
ggplot() + 
  geom_line(aes(x=x, y=y), color='blue') +
  xlab('Date') + ylab('Residuals') + 
  theme_bw() + theme(text=element_text(size=16))
# Out:
# plot without title

# %% [markdown]
# Regression standardized residuals seem to be fairly noisy, with no obvious trend.
